# %%
import os
import pandas as pd

# %%
path = "../data/folketinget_data/"

# %%
files = os.listdir(path)

# %%
print(files)
# Out:
# ['Afstemning.json', 'Afstemningstype.json', 'Aktoer.json', 'AktoerAktoer.json', 'AktoerAktoerRolle.json', 'Aktoertype.json', 'Aktstykke.json', 'Almdel.json', 'Dagsordenspunkt.json', 'DagsordenspunktDokument.json', 'DagsordenspunktSag.json', 'Debat.json', 'Dokument.json', 'Dokumentkategori.json', 'Dokumentstatus.json', 'Dokumenttype.json', 'Fil.json', 'folketinget_data.csv', 'folketinget_data_latest.csv', 'Forslag.json', 'KolloneBeskrivelse.json', 'Moede.json', 'MoedeAktoer.json', 'Moedestatus.json', 'Moedetype.json', 'Omtryk.json', 'Periode.json', 'Sag.json', 'SagAktoer.json', 'SagAktoerRolle.json', 'SagDokument.json', 'SagDokumentRolle.json', 'Sagskategori.json', 'Sagsstatus.json', 'Sagstrin.json', 'SagstrinAktoer.json', 'SagstrinAktoerRolle.json', 'SagstrinDokument.json', 'Sagstrinsstatus.json', 'Sagstrinstype.json', 'Sagstype.json', 'Stemme.json', 'Stemmetype.json']

# %%
len(files)
# Out:
# 43

# %%
'Afstemning.json', 'Afstemningstype.json'
# Out:
# ('Afstemning.json', 'Afstemningstype.json')

# %%
afstemning = pd.read_csv(path+files[0])

# %%
afstemning
# Out:
#         id  nummer                                         konklusion  \
# 0        1     411  Vedtaget\n\n108 stemmer for forslaget (V, S, D...
# 1        2     412  Vedtaget\n\n98 stemmer for forslaget (V, S, DF...
# 2        3       1  Vedtaget\n\n59 stemmer for forslaget (S, RV, S...
# 3        4       7  Vedtaget\n\n72 stemmer for forslaget (S, DF, R...
# 4        5     412  Vedtaget\n\n98 stemmer for forslaget (V, S, DF...
# ...    ...     ...                                                ...
# 8295  8372     747  Forslaget blev forkastet. For stemte 29 (DF, S...
# 8296  8373     748  Forslaget blev forkastet. For stemte 20 (SF, E...
# 8297  8374     749  Forslaget blev forkastet. For stemte 31 (DF, S...
# 8298  8375     751  Forslaget blev vedtaget. For stemte 71 (S, V, ...
# 8299  8376       2  Forslaget blev vedtaget. For stemte 57 (S, SF,...
#
#       vedtaget                                          kommentar  mødeid  \
# ...

# %%
afstemnings_type = pd.read_csv(path+files[1])

# %%
afstemnings_type
# Out:
#    id                    type          opdateringsdato
# 0   1      Endelig vedtagelse  2014-08-06T14:40:50.207
# 1   2      Udvalgsindstilling  2014-08-06T14:40:50.207
# 2   3  Forslag til vedtagelse  2014-08-06T14:40:50.207
# 3   4         Ændringsforslag  2014-08-06T14:40:50.207

# %%
afstemning.merge(afstemnings_type, how="left", left_on="typeid", right_on="id", ).drop('id_y', axis=1).rename(columns={"id_x":"id"})
# Out:
#         id  nummer                                         konklusion  \
# 0        1     411  Vedtaget\n\n108 stemmer for forslaget (V, S, D...
# 1        2     412  Vedtaget\n\n98 stemmer for forslaget (V, S, DF...
# 2        3       1  Vedtaget\n\n59 stemmer for forslaget (S, RV, S...
# 3        4       7  Vedtaget\n\n72 stemmer for forslaget (S, DF, R...
# 4        5     412  Vedtaget\n\n98 stemmer for forslaget (V, S, DF...
# ...    ...     ...                                                ...
# 8295  8372     747  Forslaget blev forkastet. For stemte 29 (DF, S...
# 8296  8373     748  Forslaget blev forkastet. For stemte 20 (SF, E...
# 8297  8374     749  Forslaget blev forkastet. For stemte 31 (DF, S...
# 8298  8375     751  Forslaget blev vedtaget. For stemte 71 (S, V, ...
# 8299  8376       2  Forslaget blev vedtaget. For stemte 57 (S, SF,...
#
#       vedtaget                                          kommentar  mødeid  \
# ...

# %%
'Aktoer.json', 'AktoerAktoer.json', 'AktoerAktoerRolle.json', 'Aktoertype.json'
# Out:
# ('Aktoer.json',
#  'AktoerAktoer.json',
#  'AktoerAktoerRolle.json',
#  'Aktoertype.json')

# %%
aktøer = pd.read_csv(path+files[2])
aktøeraktøer = pd.read_csv(path+files[3])
aktøeraktøerrolle = pd.read_csv(path+files[4])
aktøertype = pd.read_csv(path+files[5])

# %%
aktøer
# Out:
#           id  typeid                 gruppenavnkort  \
# 0          1       3                            FIU
# 1          2       1                            NaN
# 2          3       2                 finansminister
# 3          4       2  økonomi- og indenrigsminister
# 4          5       5                            NaN
# ...      ...     ...                            ...
# 17200  19931      12                            NaN
# 17201  19933       4                            UFG
# 17202  19935      12                            NaN
# 17203  19936      13                            SDG
# 17204  19937      13                           SRSR
#
#                                                     navn    fornavn efternavn  \
# 0                                         Finansudvalget        NaN       NaN
# 1                                      Finansministeriet        NaN       NaN
# 2                                       finansministeren        NaN       NaN
# ...

# %%
aktøeraktøer
# Out:
#               id  fraaktørid  tilaktørid            startdato slutdato  \
# 0              3           1         264  2013-10-02T00:00:00      NaN
# 1              4           1         201  2014-06-16T00:00:00      NaN
# 2              5           1           5  2014-06-19T00:00:00      NaN
# 3              7           1         173  2013-10-02T00:00:00      NaN
# 4              8           1          98  2013-10-02T00:00:00      NaN
# ...          ...         ...         ...                  ...      ...
# 124261  28264723         213       19897  2021-10-06T00:00:00      NaN
# 124262  28264724         139       19897  2021-10-06T00:00:00      NaN
# 124263  28264725         274       19897  2021-10-06T00:00:00      NaN
# 124264  28264726         275       19897  2021-10-06T00:00:00      NaN
# 124265  28264727       15963       19897  2021-10-06T00:00:00      NaN
#
#                 opdateringsdato  rolleid
# 0        2014-08-11T13:51:38.45       15
# ...

# %%
aktøeraktøerrolle
# Out:
#     id                 rolle          opdateringsdato
# 0    1        1. næstformand   2015-05-29T14:49:17.54
# 1    2      udvalgsassistent   2015-04-22T12:53:24.92
# 2    3    Tidligere minister  2014-08-06T14:43:17.187
# 3    4      udvalgssekretær2  2014-08-06T14:43:17.187
# 4    5        3. næstformand  2014-08-06T14:43:17.187
# 5    6    orlov med vederlag  2015-02-10T14:45:59.597
# 6    7  folketingets formand  2014-08-06T14:43:17.187
# 7    8              Minister  2015-07-06T13:36:24.093
# 8    9        2. næstformand  2014-08-06T14:43:17.187
# 9   10         stedfortræder  2015-08-13T10:24:26.357
# 10  11        4. næstformand  2014-08-06T14:43:17.187
# 11  12   orlov uden vederlag  2014-10-16T21:09:23.957
# 12  13       udvalgssekretær  2015-04-23T15:53:56.433
# 13  14           næstformand  2015-07-07T11:42:46.047
# 14  15                medlem  2015-06-03T13:28:02.543
# 15  16               formand  2015-04-24T14:39:50.027
# ...

# %%
aktøeraktøer.merge(aktøeraktøerrolle, how="left", left_on="rolleid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})
# Out:
#               id  fraaktørid  tilaktørid            startdato slutdato  \
# 0              3           1         264  2013-10-02T00:00:00      NaN
# 1              4           1         201  2014-06-16T00:00:00      NaN
# 2              5           1           5  2014-06-19T00:00:00      NaN
# 3              7           1         173  2013-10-02T00:00:00      NaN
# 4              8           1          98  2013-10-02T00:00:00      NaN
# ...          ...         ...         ...                  ...      ...
# 124261  28264723         213       19897  2021-10-06T00:00:00      NaN
# 124262  28264724         139       19897  2021-10-06T00:00:00      NaN
# 124263  28264725         274       19897  2021-10-06T00:00:00      NaN
# 124264  28264726         275       19897  2021-10-06T00:00:00      NaN
# 124265  28264727       15963       19897  2021-10-06T00:00:00      NaN
#
#               opdateringsdato_x  rolleid             rolle  \
# ...

# %%
aktøertype
# Out:
#     id                       type          opdateringsdato
# 0    1             Ministerområde   2015-08-13T11:22:10.49
# 1    2              Ministertitel  2015-08-13T10:47:17.533
# 2    3                     Udvalg  2015-07-03T12:30:41.907
# 3    4           Folketingsgruppe  2015-05-11T13:25:06.573
# 4    5                     Person  2015-07-23T14:08:13.347
# 5    6                     Gruppe  2014-08-06T14:43:17.187
# 6    7               Anden gruppe  2014-08-06T14:43:17.187
# 7    8                Ministerium  2014-08-06T14:43:17.187
# 8    9                 Kommission  2015-06-02T14:57:33.623
# 9   10               Organisation  2015-07-15T13:11:55.147
# 10  11  Parlamentarisk forsamling  2015-06-03T13:28:02.543
# 11  12               Privatperson   2015-07-09T13:39:05.05
# 12  13       Tværpolitisk netværk  2020-10-05T16:15:21.907

# %%
aktøer.merge(aktøertype, how="left", left_on="typeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})
# Out:
#           id  typeid                 gruppenavnkort  \
# 0          1       3                            FIU
# 1          2       1                            NaN
# 2          3       2                 finansminister
# 3          4       2  økonomi- og indenrigsminister
# 4          5       5                            NaN
# ...      ...     ...                            ...
# 17200  19931      12                            NaN
# 17201  19933       4                            UFG
# 17202  19935      12                            NaN
# 17203  19936      13                            SDG
# 17204  19937      13                           SRSR
#
#                                                     navn    fornavn efternavn  \
# 0                                         Finansudvalget        NaN       NaN
# 1                                      Finansministeriet        NaN       NaN
# 2                                       finansministeren        NaN       NaN
# ...

# %%
'Aktstykke.json', 'Almdel.json',
# Out:
# ('Aktstykke.json', 'Almdel.json')

# %%
aktstykke = pd.read_csv(path+files[6])

# %%
aktstykke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4199 entries, 0 to 4198
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      4199 non-null   int64
#  1   typeid                  4199 non-null   int64
#  2   kategoriid              4199 non-null   int64
#  3   statusid                4199 non-null   int64
#  4   titel                   4199 non-null   object
#  5   titelkort               4199 non-null   object
#  6   offentlighedskode       4199 non-null   object
#  7   nummer                  4199 non-null   object
#  8   nummerprefix            4199 non-null   object
#  9   nummernumerisk          4199 non-null   int64
#  10  nummerpostfix           283 non-null    object
#  11  resume                  4160 non-null   object
#  12  afstemningskonklusion   3622 non-null   object
#  13  periodeid               4199 non-null   int64
# ...

# %%
aktstykke.head()
# Out:
#    id  typeid  kategoriid  statusid  \
# 0  66       3          13        11
# 1  68       3          13        11
# 2  69       3          13        11
# 3  70       3          13        11
# 4  71       3          13        11
#
#                                                titel  \
# 0  Forslag til lov om tillægsbevilling for finans...
# 1  Forslag til lov om ændring af lov om Det Centr...
# 2       Forslag til lov om Danmarks Innovationsfond.
# 3  Forslag til lov om ændring af lov om forskning...
# 4  Forslag til lov om ændring af lov om teknologi...
#
#                                            titelkort offentlighedskode nummer  \
# 0     Om tillægsbevillingsloven for finansåret 2013.                 O  L 105
# 1  Om tildeling af nyt personnummer i særlige til...                 O  L 110
# 2                       Om Danmarks Innovationsfond.                 O  L 107
# 3  Om konsekvensændringer som følge af lov om Dan...                 O  L 109
# ...

# %%
almdel = pd.read_csv(path+files[7])

# %%
almdel.columns
# Out:
# Index(['id', 'typeid', 'kategoriid', 'statusid', 'titel', 'titelkort',
#        'offentlighedskode', 'nummer', 'nummerprefix', 'nummernumerisk',
#        'nummerpostfix', 'resume', 'afstemningskonklusion', 'periodeid',
#        'afgørelsesresultatkode', 'baggrundsmateriale', 'opdateringsdato',
#        'statsbudgetsag', 'begrundelse', 'paragrafnummer', 'paragraf',
#        'afgørelsesdato', 'afgørelse', 'rådsmødedato', 'lovnummer',
#        'lovnummerdato', 'retsinformationsurl', 'fremsatundersagid',
#        'deltundersagid'],
#       dtype='object')

# %%
almdel.head()
# Out:
#       id  typeid  kategoriid  statusid       titel   titelkort  \
# 0   7337       1         NaN         1  UPN UM-del  UPN UM-del
# 1   7338       1         NaN         1  UPN UM-del  UPN UM-del
# 2   7339       1         NaN         1  UPN UM-del  UPN UM-del
# 3   7344       1         NaN         1  UPN UM-del  UPN UM-del
# 4  35738       1         NaN         1  UPN UM-del  UPN UM-del
#
#   offentlighedskode  nummer  nummerprefix  nummernumerisk  ...  \
# 0                 O     NaN           NaN             NaN  ...
# 1                 O     NaN           NaN             NaN  ...
# 2                 O     NaN           NaN             NaN  ...
# 3                 O     NaN           NaN             NaN  ...
# 4                 O     NaN           NaN             NaN  ...
#
#    paragrafnummer  paragraf  afgørelsesdato  afgørelse  rådsmødedato  \
# 0             NaN       NaN             NaN        NaN           NaN
# ...

# %%
'Dagsordenspunkt.json', 'DagsordenspunktDokument.json'
# Out:
# ('Dagsordenspunkt.json', 'DagsordenspunktDokument.json')

# %%
dagsordenspunkt = pd.read_csv(path+files[8])
dagsordenspunkt
# Out:
#           id  kørebemærkning  \
# 0          1             NaN
# 1          2             NaN
# 2          3             NaN
# 3          4             NaN
# 4          5             NaN
# ...      ...             ...
# 26028  71888             NaN
# 26029  71889             NaN
# 26030  71890             NaN
# 26031  71891             NaN
# 26032  71892             NaN
#
#                                                    titel kommentar nummer  \
# 0      Drøftelse og afgivelse af tilsynets årlige ber...       NaN      1
# 1      Drøftelse af svar fra Region Sjælland vedr. ti...       NaN      2
# 2      Drøftelse af evalueringen af ordningen med tvu...       NaN      3
# 3      Svar vedr. hvilke regler der gælder for tvangs...       NaN      4
# 4      Svar vedr. en nærmere redegørelse for, hvilke ...       NaN      5
# ...                                                  ...       ...    ...
# 26028                                         Eventuelt.       NaN      4
# ...

# %%
dagsordenspunkt.head()
# Out:
#    id  kørebemærkning                                              titel  \
# 0   1             NaN  Drøftelse og afgivelse af tilsynets årlige ber...
# 1   2             NaN  Drøftelse af svar fra Region Sjælland vedr. ti...
# 2   3             NaN  Drøftelse af evalueringen af ordningen med tvu...
# 3   4             NaN  Svar vedr. hvilke regler der gælder for tvangs...
# 4   5             NaN  Svar vedr. en nærmere redegørelse for, hvilke ...
#
#   kommentar nummer forhandlingskode  forhandling  superid  sagstrinid  mødeid  \
# 0       NaN      1              NaN          NaN      NaN         NaN       4
# 1       NaN      2              NaN          NaN      NaN         NaN       4
# 2       NaN      3              NaN          NaN      NaN         NaN       4
# 3       NaN      4              NaN          NaN      NaN         NaN       4
# 4       NaN      5              NaN          NaN      NaN         NaN       4
#
#   offentlighedskode          opdateringsdato
# ...

# %%
dagsordenspunktdokument = pd.read_csv(path+files[9])

# %%
dagsordenspunktdokument.head()
# Out:
#    id  dokumentid  dagsordenspunktid note          opdateringsdato
# 0   2       11612                 67  NaN   2014-09-10T13:17:24.08
# 1   3       10777                 69  NaN   2014-09-10T14:50:00.71
# 2   4       10778                 69  NaN   2014-09-10T14:50:00.71
# 3   6       25419                 83  NaN  2014-09-11T13:01:38.527
# 4   7       25619                 74  NaN   2014-09-12T10:31:42.19

# %%
dagsorden = dagsordenspunkt.merge(dagsordenspunktdokument, how="left", left_on="id", right_on="dagsordenspunktid").drop("id_y", axis=1).rename(columns={"id_x": "id"})

# %%
dagsorden
# Out:
#           id  kørebemærkning  \
# 0          1             NaN
# 1          2             NaN
# 2          3             NaN
# 3          4             NaN
# 4          5             NaN
# ...      ...             ...
# 39638  71888             NaN
# 39639  71889             NaN
# 39640  71890             NaN
# 39641  71891             NaN
# 39642  71892             NaN
#
#                                                    titel kommentar nummer  \
# 0      Drøftelse og afgivelse af tilsynets årlige ber...       NaN      1
# 1      Drøftelse af svar fra Region Sjælland vedr. ti...       NaN      2
# 2      Drøftelse af evalueringen af ordningen med tvu...       NaN      3
# 3      Svar vedr. hvilke regler der gælder for tvangs...       NaN      4
# 4      Svar vedr. en nærmere redegørelse for, hvilke ...       NaN      5
# ...                                                  ...       ...    ...
# 39638                                         Eventuelt.       NaN      4
# ...

# %%
dagsorden.merge(dagsordenspunktsag, how="left", on="dagsordenspunktid").drop("id_y", axis=1).rename(columns={"id_x":"id"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-cdc194bbbe77> in <module>
# ----> 1 dagsorden.merge(dagsordenspunktsag, how="left", on="dagsordenspunktid").drop("id_y", axis=1).rename(columns={"id_x":"id"})
#       2
#
# NameError: name 'dagsordenspunktsag' is not defined

# %%
'DagsordenspunktSag.json', 'Debat.json', 'Dokument.json', 'Dokumentkategori.json', 'Dokumentstatus.json', 'Dokumenttype.json'
# Out:
# ('DagsordenspunktSag.json',
#  'Debat.json',
#  'Dokument.json',
#  'Dokumentkategori.json',
#  'Dokumentstatus.json',
#  'Dokumenttype.json')

# %%
dagsordenspunktsag = pd.read_csv(path+files[10])

# %%
dagsordenspunktsag
# Out:
#          id  dagsordenspunktid  sagid          opdateringsdato
# 0         3                101   6900  2014-09-16T15:57:33.623
# 1         4                100    648  2014-09-16T15:57:33.623
# 2         6                102   6901  2014-09-16T15:57:33.623
# 3         7                103   6902  2014-09-16T15:57:33.623
# 4        11               3748   2230  2014-09-19T14:23:57.567
# ...     ...                ...    ...                      ...
# 5854  29529              71747  89758  2021-10-12T09:21:29.947
# 5855  29530              71890  89758   2021-10-12T09:21:29.96
# 5856  29531              71768  89749   2021-10-12T09:26:28.71
# 5857  29532              71892  89619  2021-10-12T10:04:38.157
# 5858  29533              71605  89619  2021-10-12T10:04:38.157
#
# [5859 rows x 4 columns]

# %%
debat = pd.read_csv(path+files[11])

# %%
debat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2417 entries, 0 to 2416
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      2417 non-null   int64
#  1   typeid                  2417 non-null   int64
#  2   kategoriid              576 non-null    float64
#  3   statusid                2417 non-null   int64
#  4   titel                   2417 non-null   object
#  5   titelkort               2417 non-null   object
#  6   offentlighedskode       2417 non-null   object
#  7   nummer                  2415 non-null   object
#  8   nummerprefix            325 non-null    object
#  9   nummernumerisk          325 non-null    float64
#  10  nummerpostfix           0 non-null      float64
#  11  resume                  42 non-null     object
#  12  afstemningskonklusion   0 non-null      float64
#  13  periodeid               2417 non-null   int64
# ...

# %%
dokument = pd.read_csv(path+files[12])
# Out:
# /home/carbon/.conda/envs/flow/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dokument.head()
# Out:
#    id  typeid  kategoriid  statusid offentlighedskode  \
# 0   1      13          36         1                 O
# 1   2      16          14         1                 O
# 2   3      17          22         1                 O
# 3   4      16          14         1                 O
# 4   5      17          22         1                 O
#
#                                                titel                 dato  \
# 0  Spm. om formuefordelingen fordelt på både indk...  2014-08-08T00:00:00
# 1  Er ministeren enig i vurderingen af, at grønla...  2014-01-02T00:00:00
# 2  Svar på spm. nr. S 725: Er ministeren enig i v...  2014-01-09T00:00:00
# 3  Hvad agter ministeren at foretage sig, så kost...  2014-01-02T00:00:00
# 4  Svar på spm. nr. S 726: Hvad agter ministeren ...  2014-01-08T00:00:00
#
#        modtagelsesdato      frigivelsesdato paragraf  paragrafnummer  \
# 0                  NaN  2014-08-08T14:57:26      NaN             NaN
# ...

# %%
dokumentkategori = pd.read_csv(path+files[13])
dokument_status = pd.read_csv(path+files[14])
dokumenttype = pd.read_csv(path+files[15])

# %%
dokumentkategori
# Out:
#     id                      kategori          opdateringsdato
# 0    1            Beslutningsreferat   2014-09-11T17:44:36.23
# 1    2              Pressemeddelelse  2014-08-06T14:43:17.187
# 2    3         Forslag til afgørelse   2014-06-24T15:24:23.66
# 3    4                       Hvidbog  2014-08-06T14:43:17.187
# 4    5                   Redegørelse   2014-06-24T15:24:23.66
# ..  ..                           ...                      ...
# 78  79               Arbejdsdokument   2015-06-01T15:10:32.86
# 79  80    Forslag til rammeafgørelse  2015-06-26T10:51:50.327
# 80  81          Indkommende dokument  2015-09-16T14:19:37.723
# 81  82  Internt notat med opfølgning  2015-09-16T14:19:37.723
# 82  83       Godkendelsesindstilling  2015-09-16T14:19:37.723
#
# [83 rows x 3 columns]

# %%
dokument_status
# Out:
#    id        status          opdateringsdato
# 0   1      Endeligt  2015-07-15T09:44:04.857
# 1   2          Låst  2014-09-27T11:37:32.857
# 2   3        Omdelt   2014-11-13T10:31:39.22
# 3   4  Tilbagetaget  2014-09-19T09:03:42.327
# 4   5    Foreløbigt  2015-09-16T14:19:37.723

# %%
dokumenttype
# Out:
#     id                     type          opdateringsdato
# 0    1              Redegørelse  2015-05-20T13:01:40.133
# 1    2        Stedfortræderbrev  2014-08-06T14:43:17.187
# 2    3      Ministerredegørelse  2015-03-04T11:11:40.247
# 3    4                Aktstykke   2015-07-06T14:27:03.72
# 4    5             Forespørgsel  2015-03-25T13:39:31.217
# 5    6                  EU-note  2014-10-06T09:22:10.703
# 6    7        Fremsættelsestale  2015-03-26T10:06:41.623
# 7    8                  Referat  2014-08-06T14:43:17.187
# 8    9       Formandsmeddelelse  2014-08-06T14:43:17.187
# 9   10                    Notat  2014-09-29T11:26:54.447
# 10  11   Statsrevisorbemærkning  2014-10-11T01:33:50.333
# 11  12                    Bilag  2015-05-27T13:57:25.723
# 12  13                Spørgsmål  2015-05-26T14:37:05.147
# 13  14       Indstilling til EB  2014-08-06T14:43:17.187
# 14  15                Beretning  2014-08-06T14:43:17.187
# ...

# %%
dokument = dokument.merge(dokumentkategori, how="left", left_on="kategoriid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
dokument = dokument.merge(dokument_status, how="left", left_on="statusid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
dokument = dokument.merge(dokumenttype, how="left", left_on="typeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
dokument.head()
# Out:
#    id  typeid  kategoriid  statusid offentlighedskode  \
# 0   1      13          36         1                 O
# 1   2      16          14         1                 O
# 2   3      17          22         1                 O
# 3   4      16          14         1                 O
# 4   5      17          22         1                 O
#
#                                                titel                 dato  \
# 0  Spm. om formuefordelingen fordelt på både indk...  2014-08-08T00:00:00
# 1  Er ministeren enig i vurderingen af, at grønla...  2014-01-02T00:00:00
# 2  Svar på spm. nr. S 725: Er ministeren enig i v...  2014-01-09T00:00:00
# 3  Hvad agter ministeren at foretage sig, så kost...  2014-01-02T00:00:00
# 4  Svar på spm. nr. S 726: Hvad agter ministeren ...  2014-01-08T00:00:00
#
#        modtagelsesdato      frigivelsesdato paragraf  ...  procedurenummer  \
# 0                  NaN  2014-08-08T14:57:26      NaN  ...              NaN
# ...

# %%
len(dokument)
# Out:
# 817425

# %%
'Fil.json', 'Forslag.json', 'KolloneBeskrivelse.json'
# Out:
# ('Fil.json', 'Forslag.json', 'KolloneBeskrivelse.json')

# %%
fil = pd.read_csv(path+files[16])

# %%
fil
# Out:
#              id  dokumentid  \
# 0           158       11432
# 1           159       11432
# 2           160       11432
# 3           162       11430
# 4           164       11433
# ...         ...         ...
# 416827  1629166      944555
# 416828  1629177      944559
# 416829  1629184      944561
# 416830  1629187      944562
# 416831  1629199      944567
#
#                                                     titel  \
# 0       Evaluering af lov om friplejeboliger_endelig v...
# 1       Redegørelse for evaluering af friplejeboliglov...
# 2       Redegørelse for evaluering af friplejeboliglov...
# 3       EU-note om indførsel af tysk infrastrukturafgi...
# 4       Yderligere Suppl Bemærkninger til L200 - Skatt...
# ...                                                   ...
# 416827                               Udvalgsspørgsmål.pdf
# 416828           (20201) FiU L239 - svar på spørgsmål 118
# 416829                  FiU L 239 - svar på spørgsmål 112
# ...

# %%
fil_dokument = fil.merge(dokument, how="left", left_on="dokumentid", right_on="id")

# %%
forslag = pd.read_csv(path+files[17])

# %%
forslag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3304 entries, 0 to 3303
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      3304 non-null   int64
#  1   typeid                  3304 non-null   int64
#  2   kategoriid              0 non-null      float64
#  3   statusid                3304 non-null   int64
#  4   titel                   3304 non-null   object
#  5   titelkort               3304 non-null   object
#  6   offentlighedskode       3304 non-null   object
#  7   nummer                  3304 non-null   object
#  8   nummerprefix            3304 non-null   object
#  9   nummernumerisk          3304 non-null   int64
#  10  nummerpostfix           0 non-null      float64
#  11  resume                  13 non-null     object
#  12  afstemningskonklusion   0 non-null      float64
#  13  periodeid               3304 non-null   int64
# ...

# %%
kolonnebeskrivelse = pd.read_csv(path+files[18])

# %%
kolonnebeskrivelse
# Out:
#       id entitetnavn   kollonenavn  \
# 0      0  Afstemning            id
# 1      1  Afstemning     kommentar
# 2      2  Afstemning    konklusion
# 3      3  Afstemning        mødeid
# 4      4  Afstemning        nummer
# ..   ...         ...           ...
# 219  219  SyncLogger     eksternId
# 220  220  SyncLogger       entitet
# 221  221  SyncLogger  godkendtdato
# 222  222  SyncLogger            id
# 223  223  SyncLogger      internId
#
#                                            beskrivelse         opdateringsdato
# 0                         Unik identifikation af Aktør  2015-09-24T12:48:31.82
# 1    Afstemningskommentar (ændring af stemmer ved f...  2015-09-24T12:48:31.82
# 2    Afstemningsresultat, hvor der stemmes om et fo...  2015-09-24T12:48:31.82
# 3                     En afstemning foregår i et møde.  2015-09-24T12:48:31.82
# 4    Afstemningsnummer, fortløbende indenfor en per...  2015-09-24T12:48:31.82
# ...

# %%
'Moede.json', 'MoedeAktoer.json', 'Moedestatus.json', 'Moedetype.json'
# Out:
# ('Moede.json', 'MoedeAktoer.json', 'Moedestatus.json', 'Moedetype.json')

# %%
møde = pd.read_csv(path+files[19])
mødeaktøer = pd.read_csv(path+files[20])
mødestatus = pd.read_csv(path+files[21])
mødetype = pd.read_csv(path+files[22])

# %%
møde
# Out:
#          id                                      titel lokale nummer  \
# 0         1                      Møde i REU den 8/9-14  2-080    NaN
# 1         2  MIU - Ekspertmøde om EU´s affaldsdirektiv  1-133    NaN
# 2         3             MIU - Dep. - Åbent samråd (AL)  2-080    NaN
# 3         4                            Møde den 9/9-14  1-008    NaN
# 4         5                      Møde i REU den 9/9-14  S-092    NaN
# ...     ...                                        ...    ...    ...
# 9683  11978            Social- og Ældreudvalget - dep.  S-092    NaN
# 9684  11979                           Sundhedsudvalget  2-011    NaN
# 9685  11980                           Sundhedsudvalget  2-011    NaN
# 9686  11981                        Granskningsudvalget  2-011    NaN
# 9687  11982                     Beskæftigelsesudvalget  2-011    NaN
#
#       dagsordenurl starttidsbemærkning offentlighedskode                 dato  \
# ...

# %%
mødeaktøer
# Out:
#           id  mødeid  aktørid          opdateringsdato
# 0          6       6       63  2014-09-05T11:46:31.463
# 1         15      15        6    2014-09-05T15:52:05.9
# 2        541     774        6   2014-09-19T14:20:36.44
# 3        543     777        6  2014-09-19T14:20:39.333
# 4        544     775        6  2014-09-19T14:20:39.503
# ...      ...     ...      ...                      ...
# 8926  101450   11942    19912  2021-10-12T16:05:12.047
# 8927  101453   11982    19889   2021-10-12T16:29:00.91
# 8928  101456   11943    19878  2021-10-12T16:47:59.327
# 8929  101457   11928    19911  2021-10-12T16:55:25.813
# 8930  101458   11782    19829  2021-10-12T17:02:01.837
#
# [8931 rows x 4 columns]

# %%
mødestatus
# Out:
#    id              status          opdateringsdato
# 0   1  Under forberedelse  2015-07-14T11:59:42.647
# 1   2             Afholdt  2015-03-27T10:10:52.513
# 2   3              Aflyst  2014-09-19T14:36:24.413
# 3   4      Dagsorden låst   2014-10-15T10:27:06.11
# 4   5               Udsat  2015-01-27T11:59:31.077

# %%
mødetype
# Out:
#    id              type          opdateringsdato
# 0   1      Møde i salen  2015-06-25T13:13:02.187
# 1   2       Udvalgsmøde   2015-07-03T12:33:40.64
# 2   3        Andet møde  2014-11-04T12:09:35.093
# 3   4  ConciergeMeeting    2014-06-24T15:12:59.5
# 4   5  Statsrevisormøde  2015-11-18T10:41:42.077

# %%
møde = møde.merge(mødeaktøer, how="left", left_on="id", right_on="mødeid").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
møde = møde.merge(mødestatus, how="left", left_on="statusid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
møde = møde.merge(mødetype, how="left", left_on="typeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
møde
# Out:
#          id                                      titel lokale nummer  \
# 0         1                      Møde i REU den 8/9-14  2-080    NaN
# 1         2  MIU - Ekspertmøde om EU´s affaldsdirektiv  1-133    NaN
# 2         3             MIU - Dep. - Åbent samråd (AL)  2-080    NaN
# 3         4                            Møde den 9/9-14  1-008    NaN
# 4         5                      Møde i REU den 9/9-14  S-092    NaN
# ...     ...                                        ...    ...    ...
# 9685  11978            Social- og Ældreudvalget - dep.  S-092    NaN
# 9686  11979                           Sundhedsudvalget  2-011    NaN
# 9687  11980                           Sundhedsudvalget  2-011    NaN
# 9688  11981                        Granskningsudvalget  2-011    NaN
# 9689  11982                     Beskæftigelsesudvalget  2-011    NaN
#
#       dagsordenurl starttidsbemærkning offentlighedskode                 dato  \
# ...

# %%
'Omtryk.json', 'Periode.json'
# Out:
# ('Omtryk.json', 'Periode.json')

# %%
omtryk = pd.read_csv(path+files[23])
periode = pd.read_csv(path+files[24])

# %%
omtryk
# Out:
#           id  dokumentid                     dato                begrundelse  \
# 0          1           1  2014-08-11T12:52:54.987            Ændret adressat
# 1          2        1000    2014-08-07T13:01:08.6            Ændret adressat
# 2          3        9440  2014-08-12T10:09:16.603            Ændret adressat
# 3          4        9496  2014-06-03T12:45:08.147            Ændret adressat
# 4          6        9567  2014-07-25T10:44:02.497            Ændret adressat
# ...      ...         ...                      ...                        ...
# 10525  13543      937798      2021-10-12T12:46:08  Yderligere bilag tilføjet
# 10526  13544      944219   2021-10-12T12:49:01.39          Ændret medspørger
# 10527  13545      944220   2021-10-12T12:50:08.99          Ændret medspørger
# 10528  13546      943759   2021-10-12T13:31:44.09            Ændret adressat
# 10529  13547      943760  2021-10-12T13:32:33.767            Ændret adressat
#
#                opdateringsdato
# ...

# %%
periode
# Out:
#       id            startdato             slutdato     type   kode    titel  \
# 0      1  1995-01-01T00:00:00  1995-12-31T00:00:00   finans  19951     1995
# 1      2  1996-01-01T12:00:00  1996-12-31T12:00:00   finans  19961     1996
# 2      3  2002-01-01T00:00:00  2002-12-31T00:00:00   finans  20021     2002
# 3      4  2003-01-01T00:00:00  2003-12-31T00:00:00   finans  20031     2003
# 4      5  2004-01-01T00:00:00  2004-12-31T00:00:00   finans  20041     2004
# ..   ...                  ...                  ...      ...    ...      ...
# 146  151  2019-10-01T12:00:00  2020-10-06T12:00:00  samling  20191  2019-20
# 147  152  2020-01-01T12:00:00  2020-12-31T12:00:00   finans  20201     2020
# 148  153  2020-10-06T12:00:00  2021-10-05T12:00:00  samling  20201  2020-21
# 149  154  2020-01-01T12:00:00  2021-12-31T12:00:00   finans  20211     2021
# 150  155  2021-10-05T12:00:00  2022-10-04T12:00:00  samling  20211  2021-22
#
#              opdateringsdato
# ...

# %%
møde = møde.merge(periode, how="left", left_on="periodeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
møde
# Out:
#          id                                    titel_x lokale nummer  \
# 0         1                      Møde i REU den 8/9-14  2-080    NaN
# 1         2  MIU - Ekspertmøde om EU´s affaldsdirektiv  1-133    NaN
# 2         3             MIU - Dep. - Åbent samråd (AL)  2-080    NaN
# 3         4                            Møde den 9/9-14  1-008    NaN
# 4         5                      Møde i REU den 9/9-14  S-092    NaN
# ...     ...                                        ...    ...    ...
# 9685  11978            Social- og Ældreudvalget - dep.  S-092    NaN
# 9686  11979                           Sundhedsudvalget  2-011    NaN
# 9687  11980                           Sundhedsudvalget  2-011    NaN
# 9688  11981                        Granskningsudvalget  2-011    NaN
# 9689  11982                     Beskæftigelsesudvalget  2-011    NaN
#
#       dagsordenurl starttidsbemærkning offentlighedskode                 dato  \
# ...

# %%
dokument = dokument.merge(omtryk, how="left", left_on="id", right_on="dokumentid").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
dokument
# Out:
#             id  typeid  kategoriid  statusid offentlighedskode  \
# 0            1      13          36         1                 O
# 1            2      16          14         1                 O
# 2            3      17          22         1                 O
# 3            4      16          14         1                 O
# 4            5      17          22         1                 O
# ...        ...     ...         ...       ...               ...
# 818017  949243      13          36         1                 O
# 818018  949244      13          36         1                 O
# 818019  949247      13          36         1                 O
# 818020  949252      16          14         1                 O
# 818021  949253      16          14         1                 O
#
#                                                     titel  \
# 0       Spm. om formuefordelingen fordelt på både indk...
# 1       Er ministeren enig i vurderingen af, at grønla...
# ...

# %%
'Sag.json', 'SagAktoer.json', 'SagAktoerRolle.json', 'SagDokument.json', 'SagDokumentRolle.json', 'Sagskategori.json', 'Sagsstatus.json', 'Sagstrin.json', 'SagstrinAktoer.json', 'SagstrinAktoerRolle.json', 'SagstrinDokument.json', 'Sagstrinsstatus.json', 'Sagstrinstype.json', 'Sagstype.json'
# Out:
# ('Sag.json',
#  'SagAktoer.json',
#  'SagAktoerRolle.json',
#  'SagDokument.json',
#  'SagDokumentRolle.json',
#  'Sagskategori.json',
#  'Sagsstatus.json',
#  'Sagstrin.json',
#  'SagstrinAktoer.json',
#  'SagstrinAktoerRolle.json',
#  'SagstrinDokument.json',
#  'Sagstrinsstatus.json',
#  'Sagstrinstype.json',
#  'Sagstype.json')

# %%
sag = pd.read_csv(path+files[25])
sagaktøer = pd.read_csv(path+files[26])
sagaktøerrolle = pd.read_csv(path+files[27])
sagdokument = pd.read_csv(path+files[28])
sagdokumentrolle = pd.read_csv(path+files[29])
sagkategori = pd.read_csv(path+files[30])
sagstatus = pd.read_csv(path+files[31])
sagstrin = pd.read_csv(path+files[32])
sagstrinaktøer = pd.read_csv(path+files[33])
sagstrinaktøerrolle = pd.read_csv(path+files[34])
sagstrindokument = pd.read_csv(path+files[35])
sagstrinstatus = pd.read_csv(path+files[36])
sagstrintype = pd.read_csv(path+files[37])
sagstype = pd.read_csv(path+files[38])

# %%
dokument
# Out:
#             id  typeid  kategoriid  statusid offentlighedskode  \
# 0            1      13          36         1                 O
# 1            2      16          14         1                 O
# 2            3      17          22         1                 O
# 3            4      16          14         1                 O
# 4            5      17          22         1                 O
# ...        ...     ...         ...       ...               ...
# 818017  949243      13          36         1                 O
# 818018  949244      13          36         1                 O
# 818019  949247      13          36         1                 O
# 818020  949252      16          14         1                 O
# 818021  949253      16          14         1                 O
#
#                                                     titel  \
# 0       Spm. om formuefordelingen fordelt på både indk...
# 1       Er ministeren enig i vurderingen af, at grønla...
# ...

# %%
sagaktøer
# Out:
#              id  aktørid  sagid          opdateringsdato  rolleid
# 0          2212      255    370   2014-08-11T13:23:02.27        9
# 1          2213      256    371   2014-08-11T13:23:02.52        9
# 2          2221      196    373  2014-08-11T13:23:04.003        9
# 3         23659      372   4010  2014-08-11T19:19:55.973        9
# 4         23660      174   4012   2014-08-11T19:19:56.69        9
# ...         ...      ...    ...                      ...      ...
# 367894  1564736       11  89797  2021-10-12T16:39:34.943        6
# 367895  1564737      118  89797  2021-10-12T16:39:34.943       17
# 367896  1564738    18712  89797  2021-10-12T16:39:34.943       10
# 367897  1564740    19829  89782   2021-10-12T17:04:30.44       11
# 367898  1564742    19829  89783  2021-10-12T17:05:16.943       11
#
# [367899 rows x 5 columns]

# %%
sag = sag.merge(sagaktøer, how="left", left_on="id", right_on="sagid").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagaktøerrolle
# Out:
#     id                           rolle          opdateringsdato
# 0    1                           Taler  2014-06-24T15:13:26.853
# 1    2  Ordfører for forslagsstillerne  2014-06-24T15:13:26.853
# 2    3           Tidligere henvist til  2014-06-24T15:13:26.853
# 3    4                              Af  2015-07-15T13:11:55.147
# 4    5                      Medspørger  2015-05-29T11:39:49.237
# 5    6                  Ministerområde  2015-07-06T15:03:37.307
# 6    7                       Privatist  2014-06-24T15:13:26.853
# 7    8                  Kopi sendt til  2015-01-29T09:32:58.137
# 8    9                    Relevant for  2015-07-09T13:31:43.287
# 9   10                         Spørger   2015-06-01T11:33:00.79
# 10  11                     Henvist til  2015-06-25T14:52:28.353
# 11  12                        Udsteder  2015-02-12T13:31:30.293
# 12  13                      Optaget af  2014-06-24T15:13:26.853
# 13  14                        Minister  2015-08-13T10:24:56.373
# ...

# %%
sag = sag.merge(sagaktøerrolle, how="left", left_on="rolleid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagdokument
# Out:
#              id  sagid  dokumentid   bilagsnummer      frigivelsesdato  \
# 0            21   4496        7913            NaN  2013-10-16T14:54:51
# 1            30   4886        8595            NaN  2013-11-20T13:40:45
# 2            55   4262        7515            NaN  2013-10-01T15:51:19
# 3            84   5063        8896            NaN  2013-12-02T11:05:42
# 4            87   4680        8245            NaN  2013-11-01T10:29:01
# ...         ...    ...         ...            ...                  ...
# 536579  1225576  89605      949213  Spørgsmål 129  2021-11-04T00:00:00
# 536580  1225577  89755      949214  Spørgsmål 179  2021-11-04T00:00:00
# 536581  1225578  89755      949215  Spørgsmål 180  2021-11-04T00:00:00
# 536582  1225579  89755      949216  Spørgsmål 181  2021-11-04T00:00:00
# 536583  1225580  89755      949219  Spørgsmål 182  2021-11-04T00:00:00
#
#                 opdateringsdato  rolleid
# 0        2014-09-16T06:16:53.99        4
# ...

# %%
sagdokumentrolle
# Out:
#    id              rolle          opdateringsdato
# 0   1     Tidl. jour. på  2014-09-19T14:51:24.773
# 1   2  Parallelomdelt på  2014-10-06T13:54:15.487
# 2   3        På sagstrin   2015-05-12T14:33:34.01
# 3   4   Hovedtilknytning  2015-07-15T09:44:04.857
# 4   5            Se også   2014-09-19T14:24:18.41
# 5   6           Relation  2014-06-24T15:13:41.907
# 6   7              Child  2014-06-24T15:13:41.907

# %%
sagdokument = sagdokument.merge(sagdokumentrolle, how="left", left_on="rolleid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagkategori
# Out:
#     id                                  kategori          opdateringsdato
# 0    1                    Beretning af almen art   2014-06-24T15:14:09.67
# 1    2                                  Alm. del  2015-08-13T10:24:56.373
# 2    3                                        FT   2014-06-24T15:14:09.67
# 3    4            Henvendelser uden bilagsnummer   2014-06-24T15:14:09.67
# 4    5                                   Mødesag   2014-06-24T15:14:09.67
# 5    6                                Info-noter   2014-06-24T15:14:09.67
# 6    7                                        US  2015-04-15T12:29:41.997
# 7    8                       Alm. del §-markeret   2014-06-24T15:14:09.67
# 8    9                                  EU-noter   2014-06-24T15:14:09.67
# 9   10    B1 - Privat forslag - 1. (eneste) beh.  2014-10-23T10:49:29.623
# 10  11                                         S   2015-07-22T14:39:22.49
# 11  12                            Privat forslag   2014-06-24T15:14:09.67
# ...

# %%
sag = sag.merge(sagkategori, how="left", left_on="kategoriid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstatus
# Out:
#     id                 status          opdateringsdato
# 0    1              Afsluttet   2014-06-24T15:14:55.25
# 1    2                Afgivet   2014-06-24T15:14:55.25
# 2    3              Forkastet   2014-10-09T15:32:11.19
# 3    4           Tilbagetaget  2015-05-29T13:06:13.967
# 4    5             Forhandlet   2015-04-08T11:15:51.36
# ..  ..                    ...                      ...
# 59  62       Spørgsmål afvist      2017-02-14T09:47:36
# 60  63              Foreløbig  2018-07-03T16:31:49.877
# 61  64              Forkastet   2018-07-03T16:31:49.88
# 62  65                 Afvist   2019-09-05T09:58:02.34
# 63  66  3. beh. afbrudt/udsat  2021-03-01T16:41:24.267
#
# [64 rows x 3 columns]

# %%
sag = sag.merge(sagstatus, how="left", left_on="statusid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstrin
# Out:
#             id                                              titel  \
# 0            1                                         Anmeldelse
# 1            2                              Besvarelse, skriftlig
# 2            3                                         Anmeldelse
# 3            4                              Besvarelse, skriftlig
# 4            8                                         Anmeldelse
# ...        ...                                                ...
# 189297  230787     Vand i EU’s eksterne relationer – Centralasien
# 189298  230788  Udkast til Rådets afgørelse om undertegnelse p...
# 189299  230789  Genoptagelse af åbent samråd med forsvarsminis...
# 189300  230790                                         Anmeldelse
# 189301  230792                                         Anmeldelse
#
#                        dato  sagid  typeid  folketingstidendeurl  \
# 0       2014-01-02T00:00:00      2       1                   NaN
# ...

# %%
sagstrinaktøer
# Out:
#              id  sagstrinid  aktørid          opdateringsdato  rolleid
# 0             1           1        6  2014-08-11T12:53:19.827        5
# 1             2           3        6  2014-08-11T12:53:21.013        5
# 2             6           8        6   2014-08-11T12:53:24.45        5
# 3             7          10        6   2014-08-11T12:53:25.31        5
# 4             8          13       19  2014-08-11T12:53:26.777        5
# ...         ...         ...      ...                      ...      ...
# 145266  2287209      230258    19829  2021-11-04T15:55:10.577        5
# 145267  2287210      230584    19829  2021-11-04T16:46:13.513        5
# 145268  2287211      230790    19854  2021-11-04T17:34:11.687        5
# 145269  2287212      230777    19854  2021-11-04T18:03:31.697        5
# 145270  2287213      230792    19854  2021-11-04T18:03:31.747        5
#
# [145271 rows x 5 columns]

# %%
sagstrin = sagstrin.merge(sagstrinaktøer, how="left", left_on="id", right_on="sagstrinid").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstrinaktøerrolle
# Out:
#    id                           rolle          opdateringsdato
# 0   1      Ordfører for forespørgerne   2014-09-06T07:06:53.78
# 1   2                        Ordfører  2014-11-05T11:20:07.617
# 2   3                     Besvaret af   2014-09-06T03:53:43.74
# 3   4                        Minister  2015-05-12T15:36:48.057
# 4   5                     Behandles i  2015-05-21T10:12:52.757
# 5   6  Ordfører for forslagsstillerne   2014-09-06T06:50:18.23
# 6   7                           Taler  2014-08-11T12:55:05.543
# 7   8                      Medspørger   2014-06-24T15:15:36.83

# %%
sagstrin = sagstrin.merge(sagstrinaktøerrolle, how="left", left_on="rolleid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstrindokument
# Out:
#            id  sagstrinid  dokumentid          opdateringsdato
# 0       16399       73983      365065  2015-12-01T12:44:42.937
# 1       16496       69448      327904  2015-12-03T10:42:43.313
# 2       16497       67882      365053   2015-12-03T10:45:04.97
# 3       16498       67921      365092   2015-12-03T10:45:42.97
# 4       16511      118649      365284  2015-12-03T14:18:17.883
# ...       ...         ...         ...                      ...
# 60101  409193      230784      949135  2021-11-04T15:07:43.617
# 60102  409196      230785      949145      2021-11-04T15:08:52
# 60103  409199      230786      949145  2021-11-04T15:09:16.783
# 60104  409200      230581      943762  2021-11-04T15:11:47.387
# 60105  409201      230581      943767  2021-11-04T15:11:47.387
#
# [60106 rows x 4 columns]

# %%
sagstrin = sagstrin.merge(sagstrindokument, how="left", left_on="id", right_on="sagstrinid").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstrinstatus
# Out:
#       id                              status          opdateringsdato
# 0      1  Bortfaldet (pga. tid)/tilbagetaget  2014-06-24T15:19:05.423
# 1      2         Bortfaldet (pga. procedure)  2014-06-24T15:19:05.423
# 2      3                             Endelig  2014-06-24T15:19:05.423
# 3      4                             Endelig  2014-10-06T09:23:20.483
# 4      5           Planlægges til besvarelse  2014-06-24T15:19:05.423
# ..   ...                                 ...                      ...
# 278  294                               Udsat  2021-02-19T18:16:35.413
# 279  295                               Udsat  2021-02-19T18:16:35.417
# 280  296                               Udsat   2021-02-19T18:16:35.42
# 281  297                               Udsat   2021-02-19T18:16:35.42
# 282  298                              Aflyst  2021-03-03T11:19:29.767
#
# [283 rows x 3 columns]

# %%
sagstrin = sagstrin.merge(sagstrinstatus, how="left", left_on="statusid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstrintype
# Out:
#       id                                    type          opdateringsdato
# 0      1                              Anmeldelse  2015-06-01T09:02:44.147
# 1      2                               Afgivelse  2014-10-09T10:07:46.277
# 2      3                             Forhandling  2014-09-08T15:24:06.033
# 3      4                                  Fremme   2014-06-24T15:16:40.13
# 4      5                       Forhandlingsoplæg   2014-06-24T15:16:40.13
# ..   ...                                     ...                      ...
# 102  103          Spørgetime med statsministeren  2020-10-05T18:22:53.463
# 103  104  Udvidet spørgetime med statsministeren   2020-10-05T18:22:53.47
# 104  105                                 Omtrykt  2020-10-05T18:14:32.067
# 105  106                              Deputation  2020-10-05T18:22:53.463
# 106  107                         Partilederdebat  2021-03-02T17:23:06.657
#
# [107 rows x 3 columns]

# %%
sagstrin = sagstrin.merge(sagstrintype, how="left", left_on="typeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sagstrin
# Out:
#             id                                              titel  \
# 0            1                                         Anmeldelse
# 1            2                              Besvarelse, skriftlig
# 2            3                                         Anmeldelse
# 3            4                              Besvarelse, skriftlig
# 4            8                                         Anmeldelse
# ...        ...                                                ...
# 273933  230787     Vand i EU’s eksterne relationer – Centralasien
# 273934  230788  Udkast til Rådets afgørelse om undertegnelse p...
# 273935  230789  Genoptagelse af åbent samråd med forsvarsminis...
# 273936  230790                                         Anmeldelse
# 273937  230792                                         Anmeldelse
#
#                        dato  sagid  typeid  folketingstidendeurl  \
# 0       2014-01-02T00:00:00      2       1                   NaN
# ...

# %%
sagstype
# Out:
#     id                          type          opdateringsdato
# 0    1                       UMF-del  2014-06-24T15:16:55.227
# 1    2                  Forespørgsel  2015-03-20T10:01:13.277
# 2    3                    Lovforslag  2015-05-27T13:49:30.737
# 3    4                      Alm. del  2015-08-13T10:24:56.373
# 4    5            Beslutningsforslag  2015-05-29T16:06:51.047
# 5    6                      Rådsmøde  2015-05-27T15:04:46.557
# 6    7            Kommissionsforslag   2014-12-17T10:51:32.77
# 7    8                     Aktstykke  2015-07-15T13:11:55.147
# 8    9        Forslag til vedtagelse   2015-05-22T13:12:13.42
# 9   10                § 20-spørgsmål  2015-05-22T16:22:09.413
# 10  11                   Redegørelse  2015-04-29T13:44:46.833
# 11  12  Indkaldelse af stedfortræder  2014-06-24T15:16:55.227
# 12  13              Statsrevisorerne  2014-06-24T15:16:55.227

# %%
sag = sag.merge(sagstype, how="left", left_on="typeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
sag
# Out:
#            id  typeid  kategoriid  statusid  \
# 0           1       4         2.0         8
# 1           1       4         2.0         8
# 2           2      10        11.0        20
# 3           2      10        11.0        20
# 4           2      10        11.0        20
# ...       ...     ...         ...       ...
# 368150  89872      10        11.0        22
# 368151  89872      10        11.0        22
# 368152  89872      10        11.0        22
# 368153  89872      10        11.0        22
# 368154  89872      10        11.0        22
#
#                                                     titel  \
# 0                                            FIU alm. del
# 1                                            FIU alm. del
# 2       Er ministeren enig i vurderingen af, at grønla...
# 3       Er ministeren enig i vurderingen af, at grønla...
# 4       Er ministeren enig i vurderingen af, at grønla...
# ...                                                   ...
# ...

# %%
'Stemme.json', 'Stemmetype.json'
# Out:
# ('Stemme.json', 'Stemmetype.json')

# %%
stemme = pd.read_csv(path+files[39])
stemmetype = pd.read_csv(path+files[40])

# %%
stemme = stemme.merge(stemmetype, how="left", left_on="typeid", right_on="id").drop("id_y", axis=1).rename(columns={"id_x":"id"})

# %%
stemme
# Out:
#               id  typeid  afstemningid  aktørid        opdateringsdato_x  \
# 0              1       1             1      158  2014-09-09T09:05:59.653
# 1              2       1             1       71  2014-09-09T09:05:59.653
# 2              3       1             1       50  2014-09-09T09:05:59.653
# 3              4       1             1       49  2014-09-09T09:05:59.653
# 4              5       1             1      183  2014-09-09T09:05:59.653
# ...          ...     ...           ...      ...                      ...
# 1459468  1941321       3          8381    18721   2021-10-28T14:45:29.53
# 1459469  1941322       3          8381    18723   2021-10-28T14:45:29.53
# 1459470  1941323       3          8381    18724   2021-10-28T14:45:29.53
# 1459471  1941324       3          8381    18725   2021-10-28T14:45:29.53
# 1459472  1941325       3          8381    18728   2021-10-28T14:45:29.53
#
#            type        opdateringsdato_y
# 0           For  2014-06-24T15:17:12.423
# ...

# %%
list(sag.titelkort.values)
# Out:
# ['FIU alm. del',
#  'FIU alm. del',
#  'Om NSA-aflytninger eller aflytninger fra andre interessenter af grønlandske politikere og embedsfolk.',
#  'Om NSA-aflytninger eller aflytninger fra andre interessenter af grønlandske politikere og embedsfolk.',
#  'Om NSA-aflytninger eller aflytninger fra andre interessenter af grønlandske politikere og embedsfolk.',
#  'Om NSA-aflytninger eller aflytninger fra andre interessenter af grønlandske politikere og embedsfolk.',
#  'Om NSA-aflytninger eller aflytninger fra andre interessenter af grønlandske politikere og embedsfolk.',
#  'Om NSA-aflytninger eller aflytninger fra andre interessenter af grønlandske politikere og embedsfolk.',
#  'Om at bortvise elever, der har indtaget ulovlige stoffer.',
#  'Om at bortvise elever, der har indtaget ulovlige stoffer.',
#  'Om at bortvise elever, der har indtaget ulovlige stoffer.',
#  'Om at bortvise elever, der har indtaget ulovlige stoffer.',
# ...

# %%
sag
# Out:
#            id  typeid  kategoriid  statusid  \
# 0           1       4         2.0         8
# 1           1       4         2.0         8
# 2           2      10        11.0        20
# 3           2      10        11.0        20
# 4           2      10        11.0        20
# ...       ...     ...         ...       ...
# 368150  89872      10        11.0        22
# 368151  89872      10        11.0        22
# 368152  89872      10        11.0        22
# 368153  89872      10        11.0        22
# 368154  89872      10        11.0        22
#
#                                                     titel  \
# 0                                            FIU alm. del
# 1                                            FIU alm. del
# 2       Er ministeren enig i vurderingen af, at grønla...
# 3       Er ministeren enig i vurderingen af, at grønla...
# 4       Er ministeren enig i vurderingen af, at grønla...
# ...                                                   ...
# ...

# %%
dagsordenspunktsag
# Out:
#          id  dagsordenspunktid  sagid          opdateringsdato
# 0         3                101   6900  2014-09-16T15:57:33.623
# 1         4                100    648  2014-09-16T15:57:33.623
# 2         6                102   6901  2014-09-16T15:57:33.623
# 3         7                103   6902  2014-09-16T15:57:33.623
# 4        11               3748   2230  2014-09-19T14:23:57.567
# ...     ...                ...    ...                      ...
# 5854  29529              71747  89758  2021-10-12T09:21:29.947
# 5855  29530              71890  89758   2021-10-12T09:21:29.96
# 5856  29531              71768  89749   2021-10-12T09:26:28.71
# 5857  29532              71892  89619  2021-10-12T10:04:38.157
# 5858  29533              71605  89619  2021-10-12T10:04:38.157
#
# [5859 rows x 4 columns]

# %%
dagsordenspunkt
# Out:
#           id  kørebemærkning  \
# 0          1             NaN
# 1          2             NaN
# 2          3             NaN
# 3          4             NaN
# 4          5             NaN
# ...      ...             ...
# 26028  71888             NaN
# 26029  71889             NaN
# 26030  71890             NaN
# 26031  71891             NaN
# 26032  71892             NaN
#
#                                                    titel kommentar nummer  \
# 0      Drøftelse og afgivelse af tilsynets årlige ber...       NaN      1
# 1      Drøftelse af svar fra Region Sjælland vedr. ti...       NaN      2
# 2      Drøftelse af evalueringen af ordningen med tvu...       NaN      3
# 3      Svar vedr. hvilke regler der gælder for tvangs...       NaN      4
# 4      Svar vedr. en nærmere redegørelse for, hvilke ...       NaN      5
# ...                                                  ...       ...    ...
# 26028                                         Eventuelt.       NaN      4
# ...

# %%
len(set(sag.titelkort)), len(set(sag.titel))
# Out:
# (70015, 82414)

# %%
dagsordenspunkt.titel.values
# Out:
# array(['Drøftelse og afgivelse af tilsynets årlige beretning – jf. § 71 alm. del - bilag 94 (internt).',
#        'Drøftelse af svar fra Region Sjælland vedr. tilsynsbesøg den 14. marts 2014 på Afdeling for Børne- og ungepsykiatri i Roskilde, jf. § 71 alm. del - bilag 91 (internt).',
#        'Drøftelse af evalueringen af ordningen med tvungen opfølgning, jf. § 71 alm. del - bilag 90.',
#        ...,
#        'Tivoliforeningen vedr. støtte til de omrejsende tivolier og cirkusser i vinterperioden, så de kan klare sig frem til sæsonåbning til foråret, jf. KUU alm. del – bilag 5',
#        'Modtagelse af deputation fra:',
#        'Præsteforeningen m.fl. vedr. nedlæggelse af Pensionskassen af 1950, jf. KIU alm. del - bilag 3'],
#       dtype=object)

# %%
forslag.titel.values
# Out:
# array(['Aktstykke om støtte til den 13. genopfyldning af Den afrikanske Udviklingsfond',
#        'Aktstykke om forhøjet tilskud til retshjælpsinstitutioner og Dansk Flygtningehjælp',
#        'Aktstykke om forhøjelse af nettodriftsbevillingen med 0,8 mio. kr. til Kofoeds Skole',
#        ...,
#        'Aktstykke om støtte til Nordic Sugar mhp. højere miljøbeskyttelsesniveau',
#        'Aktstykke om etablering af ladestandere i boligforeninger.',
#        'Aktstykke om tilskud til 2030-Panelet.'], dtype=object)

# %%
aktstykke.titel.values
# Out:
# array(['Forslag til lov om tillægsbevilling for finansåret 2013.',
#        'Forslag til lov om ændring af lov om Det Centrale Personregister. (Tildeling af nyt personnummer i særlige tilfælde i forbindelse med identitetsmisbrug samt ophævelse af markeringer i CPR om forskerbeskyttelse).',
#        'Forslag til lov om Danmarks Innovationsfond.', ...,
#        'Forslag til lov om ændring af lov om luftfart. (Præcisering af rammerne for indskrænkninger i adgangen til luftfart og for tildeling af tilladelse til at udføre ruteflyvning, hjemmel til krav om sikkerhedsgodkendelser m.v.).',
#        'Forslag til lov om ændring af færdselsloven og lov om produkter og markedsovervågning. (Markedsovervågning på færdselsområdet m.v.).',
#        'Forslag til lov om ændring af jernbaneloven, lov om elektrificering af jernbanen og ligningsloven. (Fravigelse af støjkrav i forbindelse med jernbaneprojekter i særlige tilfælde og kompensation herfor).'],
#       dtype=object)

# %%
aktstykke
# Out:
#          id  typeid  kategoriid  statusid  \
# 0        66       3          13        11
# 1        68       3          13        11
# 2        69       3          13        11
# 3        70       3          13        11
# 4        71       3          13        11
# ...     ...     ...         ...       ...
# 4194  89665       3          13        25
# 4195  89666       3          13        25
# 4196  89667       3          13        25
# 4197  89668       3          13        25
# 4198  89669       3          13        25
#
#                                                   titel  \
# 0     Forslag til lov om tillægsbevilling for finans...
# 1     Forslag til lov om ændring af lov om Det Centr...
# 2          Forslag til lov om Danmarks Innovationsfond.
# 3     Forslag til lov om ændring af lov om forskning...
# 4     Forslag til lov om ændring af lov om teknologi...
# ...                                                 ...
# 4194  Forslag til lov om ændring af taxiloven. (Doku...
# ...

# %%
sagdokument
# Out:
#              id  sagid  dokumentid   bilagsnummer      frigivelsesdato  \
# 0            21   4496        7913            NaN  2013-10-16T14:54:51
# 1            30   4886        8595            NaN  2013-11-20T13:40:45
# 2            55   4262        7515            NaN  2013-10-01T15:51:19
# 3            84   5063        8896            NaN  2013-12-02T11:05:42
# 4            87   4680        8245            NaN  2013-11-01T10:29:01
# ...         ...    ...         ...            ...                  ...
# 536579  1225576  89605      949213  Spørgsmål 129  2021-11-04T00:00:00
# 536580  1225577  89755      949214  Spørgsmål 179  2021-11-04T00:00:00
# 536581  1225578  89755      949215  Spørgsmål 180  2021-11-04T00:00:00
# 536582  1225579  89755      949216  Spørgsmål 181  2021-11-04T00:00:00
# 536583  1225580  89755      949219  Spørgsmål 182  2021-11-04T00:00:00
#
#               opdateringsdato_x  rolleid             rolle  \
# ...

# %%
debat
# Out:
#          id  typeid  kategoriid  statusid  \
# 0        40       6         NaN        54
# 1        80      11         NaN         5
# 2       102      11         NaN         5
# 3       105       6         NaN        54
# 4       168       6         NaN        54
# ...     ...     ...         ...       ...
# 2412  89782       6        21.0        54
# 2413  89783       6        28.0        54
# 2414  89807       6        21.0        54
# 2415  89808       6        30.0        54
# 2416  89843       6        24.0        54
#
#                                                   titel  \
# 0     Rådsmøde nr. 3288 (udenrigsanliggender) den 20...
# 1     Udenrigsministerens sikkerhedspolitiske redegø...
# 2     Udenrigsministerens redegørelse om Europarådet...
# 3     Rådsmøde nr. 3290 (økonomi og finans) den 28. ...
# 4             Det Europæiske Råd den 20.-21. marts 2014
# ...                                                 ...
# 2412  Rådsmøde (udenrigsanliggender) den 18. oktober...
# ...

# %%
# Out:
#       id  typeid  kategoriid  statusid       titel   titelkort  \
# 0   7337       1         NaN         1  UPN UM-del  UPN UM-del
# 1   7338       1         NaN         1  UPN UM-del  UPN UM-del
# 2   7339       1         NaN         1  UPN UM-del  UPN UM-del
# 3   7344       1         NaN         1  UPN UM-del  UPN UM-del
# 4  35738       1         NaN         1  UPN UM-del  UPN UM-del
# 5  44548       1         NaN         1  UPN UM-del  UPN UM-del
# 6  52305       1         NaN         1  UPN UM-del  UPN UM-del
# 7  52787       1         NaN         1  UPN UM-del  UPN UM-del
#
#   offentlighedskode  nummer  nummerprefix  nummernumerisk  ...  \
# 0                 O     NaN           NaN             NaN  ...
# 1                 O     NaN           NaN             NaN  ...
# 2                 O     NaN           NaN             NaN  ...
# 3                 O     NaN           NaN             NaN  ...
# 4                 O     NaN           NaN             NaN  ...
# ...

# %%
periode
# Out:
#       id            startdato             slutdato     type   kode    titel  \
# 0      1  1995-01-01T00:00:00  1995-12-31T00:00:00   finans  19951     1995
# 1      2  1996-01-01T12:00:00  1996-12-31T12:00:00   finans  19961     1996
# 2      3  2002-01-01T00:00:00  2002-12-31T00:00:00   finans  20021     2002
# 3      4  2003-01-01T00:00:00  2003-12-31T00:00:00   finans  20031     2003
# 4      5  2004-01-01T00:00:00  2004-12-31T00:00:00   finans  20041     2004
# ..   ...                  ...                  ...      ...    ...      ...
# 146  151  2019-10-01T12:00:00  2020-10-06T12:00:00  samling  20191  2019-20
# 147  152  2020-01-01T12:00:00  2020-12-31T12:00:00   finans  20201     2020
# 148  153  2020-10-06T12:00:00  2021-10-05T12:00:00  samling  20201  2020-21
# 149  154  2020-01-01T12:00:00  2021-12-31T12:00:00   finans  20211     2021
# 150  155  2021-10-05T12:00:00  2022-10-04T12:00:00  samling  20211  2021-22
#
#              opdateringsdato
# ...
